# %%
import numpy as np
import pandas as pd

food_ratings = pd.read_csv('MyFoodRatings.csv')
food_ratings = food_ratings.drop(['Name'], axis=1)
food_ratings.head()
# Out:
#    Chicken  Mutton  Paneer  ChowMein  SpringRolls  Momo  Sushi  Ramen  Tempura
# 0        5       5       5         0            0     0      0      0        0
# 1        4       4       4         0            0     0      0      0        0
# 2        3       3       3         0            0     0      0      0        0
# 3        2       2       2         0            0     0      0      0        0
# 4        0       0       0         2            2     2      0      0        0

# %%
U,s,VT = np.linalg.svd(food_ratings, full_matrices=True)

# %%
U.shape
# Out:
# (12, 12)

# %%
s.shape
# Out:
# (9,)

# %%
VT.shape
# Out:
# (9, 9)

# %%
pd.DataFrame(U)
# Out:
#           0             1             2             3             4   \
# 0  -0.680414  0.000000e+00  0.000000e+00  2.589087e-33  0.000000e+00
# 1  -0.544331  4.965068e-17  3.858566e-18 -1.783526e-17  2.482534e-16
# 2  -0.408248  4.385591e-33  3.197739e-34 -7.066453e-34  1.218717e-32
# 3  -0.272166 -9.930137e-17 -7.717132e-18  3.567052e-17 -4.965068e-16
# 4   0.000000 -3.262170e-01 -5.183871e-17  2.396116e-16 -2.899287e-01
# 5   0.000000 -1.631085e-01  9.778593e-17 -2.467328e-16 -1.449643e-01
# 6   0.000000 -6.643101e-01  2.624092e-33  2.332361e-33  7.474571e-01
# 7   0.000000 -6.524340e-01  1.472874e-18 -5.812257e-17 -5.798574e-01
# 8   0.000000  0.000000e+00 -5.410479e-01 -8.368126e-01  0.000000e+00
# 9   0.000000  0.000000e+00 -1.936803e-01  1.621542e-01  0.000000e+00
# 10  0.000000  0.000000e+00 -7.209069e-01  4.102129e-01  0.000000e+00
# 11  0.000000  0.000000e+00 -3.873606e-01  3.243085e-01  0.000000e+00
#
#               5             6         7         8             9   \
# ...

# %%
np.diag(s[:3])
# Out:
# array([[12.72792206,  0.        ,  0.        ],
#        [ 0.        , 10.57703788,  0.        ],
#        [ 0.        ,  0.        ,  8.84826058]])

# %%
food_ratings_5 = pd.read_csv('FoodRatings_all_same_5_4_3.csv')
food_ratings_5 = food_ratings_5.drop(['Name'], axis=1)

U,s,VT = np.linalg.svd(food_ratings_5, full_matrices=True)

print("Shape of U: ", U.shape)
print("Shape of s: ", s.shape)
print("Shape of VT: ", VT.shape)
# Out:
# Shape of U:  (12, 12)
# Shape of s:  (9,)
# Shape of VT:  (9, 9)
#               0
# 0  1.732051e+01
# 1  1.385641e+01
# 2  1.039230e+01
# 3  3.925231e-16
# 4  2.798028e-49
# 5  0.000000e+00
# 6  0.000000e+00
# 7  0.000000e+00
# 8  0.000000e+00

# %%
pd.DataFrame(s)[0].apply(lambda x: format(x, 'f'))
# Out:
# 0    17.320508
# 1    13.856406
# 2    10.392305
# 3     0.000000
# 4     0.000000
# 5     0.000000
# 6     0.000000
# 7     0.000000
# 8     0.000000
# Name: 0, dtype: object
