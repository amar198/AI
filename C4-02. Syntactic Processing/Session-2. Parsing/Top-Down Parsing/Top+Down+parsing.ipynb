# %%
#Specification of CFG
import nltk

# %%
grammar = nltk.CFG.fromstring("""
S -> NP VP
NP -> Det N | Det N PP
VP -> V | V NP | V NP PP
PP -> P NP

Det -> 'a' | 'an' | 'the'
N -> 'man' | 'park' | 'dog' | 'telescope'
V -> 'saw' | 'walked'
P -> 'in' | 'with'
""")

# %%
str = "the man saw a dog in the park with a telescope"

from nltk.parse import RecursiveDescentParser

#Using a top-down parser
rdstr = RecursiveDescentParser(grammar)

#Print each of the trees 
for tree in rdstr.parse(str.split()):
    print(tree)
# Out:
# (S
#   (NP (Det the) (N man))
#   (VP
#     (V saw)
#     (NP
#       (Det a)
#       (N dog)
#       (PP
#         (P in)
#         (NP
#           (Det the)
#           (N park)
#           (PP (P with) (NP (Det a) (N telescope))))))))
# (S
#   (NP (Det the) (N man))
#   (VP
#     (V saw)
#     (NP (Det a) (N dog))
#     (PP
#       (P in)
#       (NP
#         (Det the)
#         (N park)
#         (PP (P with) (NP (Det a) (N telescope)))))))
# (S
#   (NP (Det the) (N man))
#   (VP
#     (V saw)
#     (NP (Det a) (N dog) (PP (P in) (NP (Det the) (N park))))
#     (PP (P with) (NP (Det a) (N telescope)))))

# %%
#The last tree looks like this - 
tree
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /anaconda3/lib/python3.7/site-packages/nltk/tree.py in _repr_png_(self)
#     795                         binary_names=['gswin32c.exe', 'gswin64c.exe'],
#     796                         env_vars=['PATH'],
# --> 797                         verbose=False,
#     798                     )
#     799                 ]
#
# /anaconda3/lib/python3.7/site-packages/nltk/internals.py in find_binary(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     694     return next(
#     695         find_binary_iter(
# --> 696             name, path_to_bin, env_vars, searchpath, binary_names, url, verbose
#     697         )
#     698     )
#
# /anaconda3/lib/python3.7/site-packages/nltk/internals.py in find_binary_iter(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     678     """
#     679     for file in find_file_iter(
# --> 680         path_to_bin or name, env_vars, searchpath, binary_names, url, verbose
#     681     ):
#     682         yield file
#
# /anaconda3/lib/python3.7/site-packages/nltk/internals.py in find_file_iter(filename, env_vars, searchpath, file_names, url, verbose, finding_dir)
#     636             msg += '\n\n  For more information on %s, see:\n    <%s>' % (filename, url)
#     637         div = '=' * 75
# --> 638         raise LookupError('\n\n%s\n%s\n%s' % (div, msg, div))
#     639
#     640
#
# LookupError:
#
# ===========================================================================
# NLTK was unable to find the gs file!
# Use software specific configuration paramaters or set the PATH environment variable.
# ===========================================================================
# Tree('S', [Tree('NP', [Tree('Det', ['the']), Tree('N', ['man'])]), Tree('VP', [Tree('V', ['saw']), Tree('NP', [Tree('Det', ['a']), Tree('N', ['dog']), Tree('PP', [Tree('P', ['in']), Tree('NP', [Tree('Det', ['the']), Tree('N', ['park'])])])]), Tree('PP', [Tree('P', ['with']), Tree('NP', [Tree('Det', ['a']), Tree('N', ['telescope'])])])])])

# %%
nltk.app.rdparser()
# once the recursive descent parser application opens, 
# you can edit the 'Text' and 'Grammar' according to your requirements

# %% [markdown]
# ### Practice Question

# %%
grammar = nltk.CFG.fromstring("""
S -> NP VP
NP -> NP PP | DT NN
VP -> V JJ
PP -> IN NP

DT -> 'The' | 'the'
NN -> 'work' | 'analyst'

V -> 'is'
JJ -> 'good'
IN -> 'of'
""")

# %%
str = "The work of the analyst is good"

from nltk.parse import RecursiveDescentParser

#Using a top-down parser
rdstr = RecursiveDescentParser(grammar)

#Print each of the trees 
for tree in rdstr.parse(str.split()):
    print(tree)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-7-f53a3f0e822c> in <module>
#       7
#       8 #Print each of the trees
# ----> 9 for tree in rdstr.parse(str.split()):
#      10     print(tree)
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ...
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# /anaconda3/lib/python3.7/site-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     221                     newtree = subtree
#     222                 else:
# --> 223                     newtree = tree.copy(deep=True)
#     224                     newtree[frontier[0]] = subtree
#     225                 new_frontier = [
#
# /anaconda3/lib/python3.7/site-packages/nltk/tree.py in copy(self, deep)
#     561             return type(self)(self._label, self)
#     562         else:
# --> 563             return type(self).convert(self)
#     564
#     565     def _frozen_class(self):
#
# /anaconda3/lib/python3.7/site-packages/nltk/tree.py in convert(cls, tree)
#     552         """
#     553         if isinstance(tree, Tree):
# --> 554             children = [cls.convert(child) for child in tree]
#     555             return cls(tree._label, children)
#     556         else:
#
# /anaconda3/lib/python3.7/site-packages/nltk/tree.py in <listcomp>(.0)
#     552         """
#     553         if isinstance(tree, Tree):
# --> 554             children = [cls.convert(child) for child in tree]
#     555             return cls(tree._label, children)
#     556         else:
#
# ... last 2 frames repeated, from the frame below ...
#
# /anaconda3/lib/python3.7/site-packages/nltk/tree.py in convert(cls, tree)
#     552         """
#     553         if isinstance(tree, Tree):
# --> 554             children = [cls.convert(child) for child in tree]
#     555             return cls(tree._label, children)
#     556         else:
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
tree
